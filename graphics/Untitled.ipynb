# %%
import numpy
from matplotlib import pyplot as plt

data=numpy.genfromtxt('one_disease_offest.csv',delimiter=',')
offset_1=data[:,1]
offset_2=data[:,2]
offset_3=data[:,3]
offset_4=data[:,4]
offset_5=data[:,5]
offset_6=data[:,6]
offset_7=data[:,7]
offset_8=data[:,8]
offset_9=data[:,9]
offset_10=data[:,10]
offset_11=data[:,11]
day=data[:,0]
pair_data=numpy.genfromtxt('two_disease_offset.csv',delimiter=',')
offset_1_1=pair_data[:,2]
offset_1_2=pair_data[:,4]
offset_1_3=pair_data[:,6]
offset_1_4=pair_data[:,8]
offset_1_5=pair_data[:,10]
offset_1_6=pair_data[:,12]
offset_1_7=pair_data[:,14]
offset_1_8=pair_data[:,16]
offset_1_9=pair_data[:,18]
offset_1_10=pair_data[:,20]

flu_pair_1 = pair_data[:,1]
flu_pair_2 = pair_data[:,3]
flu_pair_3 = pair_data[:,5]
flu_pair_4 = pair_data[:,7]
flu_pair_5 = pair_data[:,9]
flu_pair_6 = pair_data[:,11]
flu_pair_7 = pair_data[:,13]
flu_pair_8 = pair_data[:,15]
flu_pair_9 = pair_data[:,17]
flu_pair_10 = pair_data[:,19]

day_pair = data[:,0]

multitask=numpy.genfromtxt('5_disease_offset.csv',delimiter=',')
multi_1 = multitask[:,1]
multi_2 = multitask[:,2]
multi_3 = multitask[:,3]
multi_4 = multitask[:,4]
multi_5 = multitask[:,5]

day_multi = multitask[:,0]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline 

color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']


fig, axs = plt.subplots(2, 3,figsize=(30,20))

ax1 = plt.subplot2grid(shape=(2,6), loc=(0,0), colspan=2)
ax2 = plt.subplot2grid((2,6), (0,2), colspan=2)
ax3 = plt.subplot2grid((2,6), (0,4), colspan=2)
ax4 = plt.subplot2grid((2,6), (1,1), colspan=2)
ax5 = plt.subplot2grid((2,6), (1,3), colspan=2)

new_xticks=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2']
new_xticks_day=[1,7,14,21,28,35]

plt.setp(ax1, xticks=[1,7,14,21,28,35], 
         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
plt.setp(ax2, xticks=[1,7,14,21,28,35], 
         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
plt.setp(ax3, xticks=[1,7,14,21,28,35], 
         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
plt.setp(ax4, xticks=[1,7,14,21,28,35], 
         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
plt.setp(ax5, xticks=[1,7,14,21,28,35], 
         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
plt.xticks(new_xticks_day, new_xticks)

ax1.plot(day,offset_1,'c',linewidth=1,color='black',  label='Flu')

ax1.plot(day_pair,flu_pair_4,'--',linewidth=0.6,color='black',  label='Flu+Listeriosis')
ax1.plot(day_pair,flu_pair_5,'--',linewidth=0.6,color='black',  label='Flu+Lyme')
ax1.plot(day_pair,flu_pair_6,'--',linewidth=0.6,color='black',  label='Flu+Malaria')
ax1.plot(day_pair,flu_pair_8,'--',linewidth=0.6,color='black',  label='Flu+Pertussis')
ax1.plot(day_multi, multi_1,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax1.set_title('Flu')
ax1.legend(loc='best')
ax1.set_xticklabels(x_koordinats)

plt.setp(axs, xticks=[1,7,14,21,28,35])
#xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
ax1.grid(True)

#ax = axs[0, 1]
#ax.xticks(day, my_xticks)
ax2.plot(day,offset_5,'c',linewidth=1,  color='black',label='Listeriosis')
ax2.plot(day_pair,offset_1_4,linestyle='--',linewidth=2,color='black',  label='Listeriosis+Flu')
ax2.plot(day_multi, multi_3,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax2.set_title('Listeriosis')
ax2.legend(loc='best')
ax2.set_xticklabels(x_koordinats)
ax2.grid(True)

#ax = axs[0, 2]
#ax.xticks(day, my_xticks)
ax3.plot(day,offset_6,'c',linewidth=1,color='black', label='Lyme')
ax3.plot(day_pair,offset_1_5,linestyle='--',linewidth=2,color='black',  label='Lyme+Flu')
ax3.plot(day_multi, multi_5,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax3.set_title('Lyme')
ax3.legend(loc='best')
ax3.set_xticklabels(x_koordinats)
ax3.grid(True)

#ax = axs[1, 0]
#ax.xticks(day, my_xticks)
ax4.plot(day,offset_7,'c',linewidth=1, color='black', label='Malaria')
ax4.plot(day,offset_1_6,linestyle='--',linewidth=2, color='black', label='Malaria+Flu')
ax4.plot(day_multi, multi_4,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax4.set_title('Malaria')
ax4.legend(loc='best')
ax4.set_xticklabels(x_koordinats)
ax4.grid(True)


#ax = axs[1, 1]
#ax.xticks(day, my_xticks)
ax5.plot(day,offset_9,'c',linewidth=1,color='black', label='Pertussis')
ax5.plot(day,offset_1_8,linestyle='--',linewidth=2,color='black', label='Pertussis+Flu')
ax5.plot(day_multi, multi_2,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax5.set_title('Pertussis')
ax5.legend(loc='best')
ax5.set_xticklabels(x_koordinats)
ax5.grid(True)

#plt.set_autoscaley_on(True)

#my_xticks = ['0,0','0,-1','0,-2','-2,0','-2,-1','-2,-2','-4,0','-4,-1','-4,-2','-6,0','-6,-1',
#'-6,-2','-8,0','-8,-1','-8,-2','-10,0','-10,-1','-10,-2','-12,0','-12,-1','-12,-2','-14,0','-14,-1',
#'-14,-2','-16,0','-16,-1','-16,-2','-18,0','-18,-1','-18,-2','-20,0','-20,-1','-20,-2','-21,0','-21,-1','-21,-2'
#]
#x_koordinats=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2']
'''
left  = 0.5  # the left side of the subplots of the figure
right = 0.9    # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.2   # the amount of h

plt.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)
'''

fig.tight_layout()
plt.savefig('all_disease_scores_timeseries.pdf',format='pdf', transparent=True, bbox_inches='tight', pad_inches=0.02)
plt.show()

# %%
ax1 = plt.subplot2grid(shape=(2,6), loc=(0,0), colspan=2)
ax2 = plt.subplot2grid((2,6), (0,2), colspan=2)
ax3 = plt.subplot2grid((2,6), (0,4), colspan=2)
ax4 = plt.subplot2grid((2,6), (1,1), colspan=2)
ax5 = plt.subplot2grid((2,6), (1,3), colspan=2)

print day
print day_pair
print day_multi
#ax1 = axs[0, 0]
ax1.plot(day,offset_1,'c',linewidth=1,color='black',  label='Flu')

ax1.plot(day_pair,flu_pair_4,':',linewidth=0.4,color='black',  label='Flu+Listeriosis')
ax1.plot(day_pair,flu_pair_5,':',linewidth=0.4,color='black',  label='Flu+Lyme')
ax1.plot(day_pair,flu_pair_6,':',linewidth=0.4,color='black',  label='Flu+Malaria')
ax1.plot(day_pair,flu_pair_8,':',linewidth=0.4,color='black',  label='Flu+Pertussis')
ax1.plot(day_multi, multi_1,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax1.set_title('Flu')
ax1.legend(loc='best')
ax1.set_xticklabels(x_koordinats)

plt.setp(axs, xticks=[1,7,14,21,28,35])
#xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])
ax1.grid(True)

#ax = axs[0, 1]
#ax.xticks(day, my_xticks)
ax2.plot(day,offset_5,'c',linewidth=1,  color='black',label='Listeriosis')
ax2.plot(day_pair,offset_1_4,linestyle='--',linewidth=2,color='black',  label='Listeriosis+Flu')
ax2.plot(day_multi, multi_3,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax2.set_title('Listeriosis')
ax2.legend(loc='best')
ax2.set_xticklabels(x_koordinats)
ax2.grid(True)

#ax = axs[0, 2]
#ax.xticks(day, my_xticks)
ax3.plot(day,offset_6,'c',linewidth=1,color='black', label='Lyme')
ax3.plot(day_pair,offset_1_5,linestyle='--',linewidth=2,color='black',  label='Lyme+Flu')
ax3.plot(day_multi, multi_5,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax3.set_title('Lyme')
ax3.legend(loc='best')
ax3.set_xticklabels(x_koordinats)
ax3.grid(True)

#ax = axs[1, 0]
#ax.xticks(day, my_xticks)
ax4.plot(day,offset_7,'c',linewidth=1, color='black', label='Malaria')
ax4.plot(day,offset_1_6,linestyle='--',linewidth=2, color='black', label='Malaria+Flu')
ax4.plot(day_multi, multi_4,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax4.set_title('Malaria')
ax4.legend(loc='best')
ax4.set_xticklabels(x_koordinats)
ax4.grid(True)


#ax = axs[1, 1]
#ax.xticks(day, my_xticks)
ax5.plot(day,offset_9,'c',linewidth=1,color='black', label='Pertussis')
ax5.plot(day,offset_1_8,linestyle='--',linewidth=2,color='black', label='Pertussis+Flu')
ax5.plot(day_multi, multi_2,linestyle='-',linewidth=3,color='black',  label='Multitask')
ax5.set_title('Pertussis')
ax5.legend(loc='best')
ax5.set_xticklabels(x_koordinats)
ax5.grid(True)
