# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

font = {'family' : 'normal',
        'weight' : 'light',
        'size'   : 20}

matplotlib.rc('font', **font)

fig, axs = plt.subplots(3, 2,figsize=(30,20))


x_koordinats=['0W,0GT','-1W,-1GT','-5W,0GT','-7W,-2GT','-11W,-1GT','-15W,0GT','-17W,-2GT','-21W,-1GT']


ax1 = plt.subplot2grid((3,2), (0,0), colspan=3)
ax1.plot(day,offset_1,':',linewidth=2,color='black',  label='Flu(STL)')
ax1.plot(day,flu_pair_4,'--',linewidth=3,marker="D",color='black',  label='Flu+Listeriosis')
ax1.plot(day,flu_pair_5,'--',linewidth=3,marker="*",color='black',  label='Flu+Lyme')
ax1.plot(day,flu_pair_6,'--',linewidth=3,marker="8", color='black',  label='Flu+Malaria')
ax1.plot(day,flu_pair_8,'--',linewidth=3,marker="1",color='black',  label='Flu+Pertussis')

ax1.plot(day, multi_1, linestyle='-', linewidth=6, color='black', label='Flu(MTL)')
#ax1.set_xticks(1,7,14,21,28,35)
#ax1.set_xticklabels(x_koordinats)
ax1.set_title('Flu')
ax1.set_xticklabels(x_koordinats)
ax1.set_xlim([1,36])

ax1.legend(loc='best')
ax1.grid(True)


ax2 = plt.subplot2grid((3,2), (1,0),colspan=1)
#ax.xticks(day, my_xticks)
ax2.plot(day,offset_5,':',linewidth=2,  color='black',label='Listeriosis(STL)')
ax2.plot(day,offset_1_4,linestyle='--',linewidth=4,color='black',  label='Listeriosis+Flu')
ax2.plot(day, multi_3, linestyle='-', linewidth=6, color='black', label='Listeriosis(MTL)')
ax2.set_title('Listeriosis')
#ax2.set_xticklabels(x_koordinats)
ax2.set_xticklabels(x_koordinats)
ax2.set_xlim([1,36])
ax2.legend(loc='best')
ax2.grid(True)

ax3 = plt.subplot2grid((3,2), (1,1), colspan=1)
#ax.xticks(day, my_xticks)
ax3.plot(day,offset_6,':',linewidth=2,color='black', label='Lyme(STL)')
ax3.plot(day,offset_1_5,linestyle='--',linewidth=4,color='black',  label='Lyme+Flu')
ax3.plot(day, multi_5, linestyle='-', linewidth=6, color='black', label='Lyme(MTL)')
#ax3.set_xticklabels(x_koordinats)
ax3.set_title('Lyme')
ax3.set_xticklabels(x_koordinats)
ax3.set_xlim([1,36])
ax3.legend(loc='best')
ax3.grid(True)

ax4 = plt.subplot2grid((3,2), (2,0), colspan=1)
#ax.xticks(day, my_xticks)
ax4.plot(day,offset_7,':',linewidth=2, color='black', label='Malaria(STL)')
ax4.plot(day,offset_1_6,linestyle='--',linewidth=4, color='black', label='Malaria+Flu')
ax4.plot(day, multi_4, linestyle='-', linewidth=6, color='black', label='Malaria(MTL)')
#ax4.set_xticklabels(x_koordinats)
ax4.set_title('Malaria')
ax4.set_xticklabels(x_koordinats)
ax4.legend(loc='best')
ax4.set_xlim([1,36])
ax4.grid(True)


ax5 = plt.subplot2grid((3,2), (2,1), colspan=1)
#ax.xticks(day, my_xticks)
ax5.plot(day,offset_9,':',linewidth=2,color='black', label='Pertussis(STL)')
ax5.plot(day,offset_1_8,linestyle='--',linewidth=4,color='black', label='Pertussis+Flu')
ax5.plot(day, multi_2, linestyle='-', linewidth=6, color='black', label='Pertussis(MTL)')
#ax5.set_xticklabels(x_koordinats)
ax5.set_title('Pertussis')
ax5.set_xticklabels(x_koordinats)
ax5.legend(loc='best')
ax5.set_xlim([1,36])
ax5.grid(True)

#fft_axes.set_autoscaley_on(False)
#ax = plt.subplot2grid((3,2), (1,0), colspan=1)
#ax.xticks(day, my_xticks)
#ax.plot(day,offset_11,'c',linewidth=3,color='black', label='Typhoid-Fever')
#ax.set_title('Typhoid-Fever')
#ax.grid(True)

#fig.delaxes(ax)
#plt.xticks(day, my_xticks)
#axes = plt.gca()
#axes.set_xlim([0,36])
fig.tight_layout()

#plt.xlabel("offset",size=10)
plt.draw()

#axes = plt.gca()
#axes.set_xlim([xmin,xmax])
#axes.set_ylim([ymin,ymax])

#plt.show()
#plt.savefig('multitask_offset4.pdf',format='pdf', transparent=True, bbox_inches='tight', pad_inches=0.02)
plt.savefig('multitask_offset8.eps', format='eps',transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
import numpy
from matplotlib import pyplot as plt

data=numpy.genfromtxt('one_disease_offest.csv',delimiter=',')
offset_1=data[:,1]
offset_2=data[:,2]
offset_3=data[:,3]
offset_4=data[:,4]
offset_5=data[:,5]
offset_6=data[:,6]
offset_7=data[:,7]
offset_8=data[:,8]
offset_9=data[:,9]
offset_10=data[:,10]
offset_11=data[:,11]
day=data[:,0]
pair_data=numpy.genfromtxt('two_disease_offset.csv',delimiter=',')
offset_1_1=pair_data[:,2]
offset_1_2=pair_data[:,4]
offset_1_3=pair_data[:,6]
offset_1_4=pair_data[:,8]
offset_1_5=pair_data[:,10]
offset_1_6=pair_data[:,12]
offset_1_7=pair_data[:,14]
offset_1_8=pair_data[:,16]
offset_1_9=pair_data[:,18]
offset_1_10=pair_data[:,20]

flu_pair_1 = pair_data[:,1]
flu_pair_2 = pair_data[:,3]
flu_pair_3 = pair_data[:,5]
flu_pair_4 = pair_data[:,7]
flu_pair_5 = pair_data[:,9]
flu_pair_6 = pair_data[:,11]
flu_pair_7 = pair_data[:,13]
flu_pair_8 = pair_data[:,15]
flu_pair_9 = pair_data[:,17]
flu_pair_10 = pair_data[:,19]

day_pair = data[:,0]

multitask=numpy.genfromtxt('5_disease_offset.csv',delimiter=',')
multi_1 = multitask[:,1]
multi_2 = multitask[:,2]
multi_3 = multitask[:,3]
multi_4 = multitask[:,4]
multi_5 = multitask[:,5]

day_multi = multitask[:,0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']

fig, axs = plt.subplots(3, 2,figsize=(30,20))


#plt.ylim(0,1)
#plt.xlim(1,36)
#plt.xticks(day, my_xticks)


#plt.setp(axs, xticks=[1,7,14,21,28,35], 
#         xticklabels=['0,0','-4,0','-8,-1','-12,-2','-18,0','-21,-2'])





#plt.set_autoscaley_on(True)


#ylim=[0,1.5]

#y = np.array([20,21,22,23])
my_xticks = ['0,0','0,-1','0,-2','-2,0','-2,-1','-2,-2','-4,0','-4,-1','-4,-2','-6,0','-6,-1',
'-6,-2','-8,0','-8,-1','-8,-2','-10,0','-10,-1','-10,-2','-12,0','-12,-1','-12,-2','-14,0','-14,-1',
'-14,-2','-16,0','-16,-1','-16,-2','-18,0','-18,-1','-18,-2','-20,0','-20,-1','-20,-2','-21,0','-21,-1','-21,-2'
]

x_koordinats=['0.0','-4,0','-8,-1','-12,-2','-18,0','-21,-2']

#ax.set_xlim(1,7,14,21,28,35)
#
#plt.xticks([-21,-14,-7,0,7])

#ax = axs[0, 0]
plt.xlim(1, 50)

ax1 = plt.subplot2grid((3,2), (0,0), colspan=3)
#ax.xticks(day, my_xticks)
ax1.plot(day,offset_1,'c',linewidth=1,color='black',  label='Flu')

ax1.plot(day,flu_pair_4,':',linewidth=2,color='black',  label='Flu+Listeriosis')
ax1.plot(day,flu_pair_5,':',linewidth=2,color='black',  label='Flu+Lyme')
ax1.plot(day,flu_pair_6,':',linewidth=2,color='black',  label='Flu+Malaria')
ax1.plot(day,flu_pair_8,':',linewidth=2,color='black',  label='Flu+Pertussis')

ax1.plot(day, multi_1, linestyle='-', linewidth=4, color='black', label='Multitask')
ax1.set_xticks(1,7,14,21,28,35)
#ax1.set_xticklabels(x_koordinats)
#ax1.set_title('Flu')
ax1.legend(loc='best')
ax1.grid(True)


ax2 = plt.subplot2grid((3,2), (1,0),colspan=1)
#ax.xticks(day, my_xticks)
ax2.plot(day,offset_5,'c',linewidth=1,  color='black',label='Listeriosis')
ax2.plot(day_pair,offset_1_4,linestyle=':',linewidth=2,color='black',  label='Listeriosis+Flu')
ax2.plot(day, multi_3, linestyle='-', linewidth=4, color='black', label='Multitask')
#ax2.set_title('Listeriosis')
#ax2.set_xticklabels(x_koordinats)
ax2.legend(loc='best')
ax2.grid(True)

ax3 = plt.subplot2grid((3,2), (1,1), colspan=1)
#ax.xticks(day, my_xticks)
ax3.plot(day,offset_6,'c',linewidth=1,color='black', label='Lyme')
ax3.plot(day_pair,offset_1_5,linestyle=':',linewidth=2,color='black',  label='Lyme+Flu')
ax3.plot(day, multi_5, linestyle='-', linewidth=4, color='black', label='Multitask')
#ax3.set_xticklabels(x_koordinats)
#ax3.set_title('Lyme')
ax3.legend(loc='best')
ax3.grid(True)

ax4 = plt.subplot2grid((3,2), (2,0), colspan=1)
#ax.xticks(day, my_xticks)
ax4.plot(day,offset_7,'c',linewidth=1, color='black', label='Malaria')
ax4.plot(day,offset_1_6,linestyle=':',linewidth=2, color='black', label='Malaria+Flu')
ax4.plot(day, multi_4, linestyle='-', linewidth=4, color='black', label='Multitask')
#ax4.set_xticklabels(x_koordinats)
#ax4.set_title('Malaria')
ax4.legend(loc='best')
ax4.grid(True)


ax5 = plt.subplot2grid((3,2), (2,1), colspan=1)
#ax.xticks(day, my_xticks)
ax5.plot(day,offset_9,'c',linewidth=1,color='black', label='Pertussis')
ax5.plot(day,offset_1_8,linestyle=':',linewidth=2,color='black', label='Pertussis+Flu')
ax5.plot(day, multi_2, linestyle='-', linewidth=4, color='black', label='Multitask')
#ax5.set_xticklabels(x_koordinats)
#ax5.set_title('Pertussis')
ax5.legend(loc='best')
ax5.grid(True)

#fft_axes.set_autoscaley_on(False)
#ax = plt.subplot2grid((3,2), (1,0), colspan=1)
#ax.xticks(day, my_xticks)
#ax.plot(day,offset_11,'c',linewidth=3,color='black', label='Typhoid-Fever')
#ax.set_title('Typhoid-Fever')
#ax.grid(True)

#fig.delaxes(ax)
#plt.xticks(day, my_xticks)
axes = plt.gca()
axes.set_xlim([0,36])
plt.draw()

fig.tight_layout()
#axes = plt.gca()
#axes.set_xlim([xmin,xmax])
#axes.set_ylim([ymin,ymax])

#plt.show()
#plt.savefig('offset10.pdf',format='pdf', transparent=True, bbox_inches='tight', pad_inches=0.02)
'''
plt.xticks(day, my_xticks)

plt.title(r'$MSE$ Values For Each Offset Day')
plt.xlabel('Offset Day')
plt.ylabel(r'$MSE$', size=12, rotation='horizontal')
#plt.axvline(x=-5,color='b',linestyle='--')
plt.plot(day,offset_1,'c',linewidth=3, color=color_sequence[0], label='Flu')
#plt.plot(day,offset_2,'c',linewidth=3, color=color_sequence[1], label='Haemophilus')
#plt.plot(day,offset_3,'c',linewidth=3, color=color_sequence[2], label='Hepatitis A')
#plt.plot(day,offset_4,'c',linewidth=3, color=color_sequence[3], label='Heptatisis C')
#plt.plot(day,offset_5,'c',linewidth=3, color=color_sequence[4], label='Listeriosis')
plt.plot(day,offset_6,'c',linewidth=3, color=color_sequence[5], label='Lyme')
#plt.plot(day,offset_7,'c',linewidth=3, color=color_sequence[6], label='Malaria')
plt.plot(day,offset_8,'c',linewidth=3, color=color_sequence[7], label='Measles')
plt.plot(day,offset_9,'c',linewidth=3, color=color_sequence[8], label='Pertussis')
#plt.plot(day,offset_10,'c',linewidth=3, color=color_sequence[9], label='Q-Fever')
#plt.plot(day,offset_11,'c',linewidth=3, color=color_sequence[10], label='Typhoid-Fever')
plt.legend(loc='best')

#plt.legend(handles=[line_up, line_down])

#plt.savefig('offset.pdf',format='pdf', transparent=True, bbox_inches='tight', pad_inches=0.02)

'''
# Out:
# "\nplt.xticks(day, my_xticks)\n\nplt.title(r'$MSE$ Values For Each Offset Day')\nplt.xlabel('Offset Day')\nplt.ylabel(r'$MSE$', size=12, rotation='horizontal')\n#plt.axvline(x=-5,color='b',linestyle='--')\nplt.plot(day,offset_1,'c',linewidth=3, color=color_sequence[0], label='Flu')\n#plt.plot(day,offset_2,'c',linewidth=3, color=color_sequence[1], label='Haemophilus')\n#plt.plot(day,offset_3,'c',linewidth=3, color=color_sequence[2], label='Hepatitis A')\n#plt.plot(day,offset_4,'c',linewidth=3, color=color_sequence[3], label='Heptatisis C')\n#plt.plot(day,offset_5,'c',linewidth=3, color=color_sequence[4], label='Listeriosis')\nplt.plot(day,offset_6,'c',linewidth=3, color=color_sequence[5], label='Lyme')\n#plt.plot(day,offset_7,'c',linewidth=3, color=color_sequence[6], label='Malaria')\nplt.plot(day,offset_8,'c',linewidth=3, color=color_sequence[7], label='Measles')\nplt.plot(day,offset_9,'c',linewidth=3, color=color_sequence[8], label='Pertussis')\n#plt.plot(day,offset_10,'c',linewidth=3, color=color_sequence[9], label='Q-Fever')\n#plt.plot(day,offset_11,'c',linewidth=3, color=color_sequence[10], label='Typhoid-Fever')\nplt.legend(loc='best')\n\n#plt.legend(handles=[line_up, line_down])\n\n#plt.savefig('offset.pdf',format='pdf', transparent=True, bbox_inches='tight', pad_inches=0.02)\n\n"

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def make_ticklabels_invisible(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        for tl in ax.get_xticklabels() + ax.get_yticklabels():
            tl.set_visible(False)


plt.figure(0)
ax1 = plt.subplot2grid((3,2), (0,0), colspan=2)
ax1.plot(day,offset_1,'c',linewidth=1,color='black',  label='Flu')
#ax1.plot(day_pair,flu_pair_4,':',linewidth=0.4,color='black',  label='Flu+Listeriosis')
#ax1.plot(day_pair,flu_pair_5,':',linewidth=0.4,color='black',  label='Flu+Lyme')
#ax1.plot(day_pair,flu_pair_6,':',linewidth=0.4,color='black',  label='Flu+Malaria')
#ax1.plot(day_pair,flu_pair_8,':',linewidth=0.4,color='black',  label='Flu+Pertussis')
#ax1.plot(day_multi, multi_1,linestyle='-',linewidth=3,color='black',  label='Multitask')
#ax1.legend(loc='best')

#ax1.xlim(day.min()*1.1, day.max()*1.1)
#ax1.ylim(offset_1.min()*1.1, offset_1.max()*1.1)


ax2 = plt.subplot2grid((3,2), (1,0))
ax3 = plt.subplot2grid((3,2), (1,1))
ax4 = plt.subplot2grid((3,2), (2, 0))
ax5 = plt.subplot2grid((3,2), (2, 1))


plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)


plt.suptitle("subplot2grid")
#make_ticklabels_invisible(plt.gcf())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-0a987102e147> in <module>()
#      19 #ax1.plot(day_multi, multi_1,linestyle='-',linewidth=3,color='black',  label='Multitask')
#      20 #ax1.legend(loc='best')
# ---> 21 ax1.xlim(day.min()*1.1, day.max()*1.1)
#      22 ax1.ylim(offset_1.min()*1.1, offset_1.max()*1.1)
#      23
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlim'

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def make_ticklabels_invisible(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        for tl in ax.get_xticklabels() + ax.get_yticklabels():
            tl.set_visible(False)


plt.figure(0)
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2, 0))
ax5 = plt.subplot2grid((3,3), (2, 1))



plt.suptitle("subplot2grid")
make_ticklabels_invisible(plt.gcf())
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


def make_ticklabels_invisible(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        for tl in ax.get_xticklabels() + ax.get_yticklabels():
            tl.set_visible(False)


plt.figure()

gs = GridSpec(3, 3)
ax1 = plt.subplot(gs[0, :])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0,0), colspan=3))
ax2 = plt.subplot(gs[1,:-1])
ax3 = plt.subplot(gs[1:, -1])
ax4 = plt.subplot(gs[-1,0])
ax5 = plt.subplot(gs[-1,-2])

plt.suptitle("GridSpec")
make_ticklabels_invisible(plt.gcf())

plt.show()

# %%
from matplotlib import pyplot
import numpy as np

fig = pyplot.figure()
xData = np.linspace(0, 4*np.pi)
yData = np.sin(xData)

# 3 rows, 2 columns, subplot 2 -> 321
pyplot.subplot("231")
pyplot.plot(xData, yData)

# 3 rows, 2 columns, subplot 2 -> 322
pyplot.subplot("232")
pyplot.plot(xData, yData)

# 3 rows, 2 columns, subplot 3 -> 323
pyplot.subplot("233")
pyplot.plot(xData, yData)


pyplot.subplot("234")
pyplot.plot(xData, yData)

# etc ...

pyplot.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)

#ax1.plot(day,offset_1,'c',linewidth=1,color='black',  label='Flu')

plt.subplot(3, 1, 1)
plt.xticks((day)), plt.yticks((offset_1))

plt.subplot(3, 2, 3)
plt.xticks(())
plt.yticks(())

plt.subplot(3, 2, 4)
plt.xticks(())
plt.yticks(())

plt.subplot(3, 2, 5)
plt.xticks(())
plt.yticks(())

plt.subplot(3, 2, 6)
plt.xticks(())
plt.yticks(())


#plt.subplot(2, 3, 6)
#plt.xticks(())
#plt.yticks(())

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec

import plotly.plotly as py
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

fig = plt.figure()
gs = gridspec.GridSpec(3, 3)
ax1 = fig.add_subplot(gs[0,:])
ax1.plot([1,2,3,4,5], [10,5,10,5,10], 'r-')
ax2 = fig.add_subplot(gs[1,:-1])
ax2.plot([1,2,3,4], [1,4,9,16], 'k-')
ax3 = fig.add_subplot(gs[1:, 2])
ax3.plot([1,2,3,4], [1,10,100,1000], 'b-')
ax4 = fig.add_subplot(gs[2,0])
ax4.plot([1,2,3,4], [0,0,1,1], 'g-')
ax5 = fig.add_subplot(gs[2,1])
ax5.plot([1,2,3,4], [1,0,0,1], 'c-')
gs.update(wspace=0.5, hspace=0.5)

fig = plt.gcf()

plotly_fig = tls.mpl_to_plotly( fig )
plotly_fig['layout']['title'] = 'Subplots with variable widths and heights'
plotly_fig['layout']['margin'].update({'t':40})

plot_url = py.plot(plotly_fig, filename='mpl-subplot-variable-width')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-79a6d6b71023> in <module>()
#      22 fig = plt.gcf()
#      23
# ---> 24 plotly_fig = tls.mpl_to_plotly( fig )
#      25 plotly_fig['layout']['title'] = 'Subplots with variable widths and heights'
#      26 plotly_fig['layout']['margin'].update({'t':40})
#
# NameError: name 'tls' is not defined

# %%
from plotly import tools
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Scatter(x=[1, 2], y=[1, 2], name='(1,1)')
trace2 = go.Scatter(x=[1, 2], y=[1, 2], name='(1,2)')
trace3 = go.Scatter(x=[1, 2], y=[1, 2], name='(2,1)')
trace4 = go.Scatter(x=[1, 2], y=[1, 2], name='(3,1)')
trace5 = go.Scatter(x=[1, 2], y=[1, 2], name='(5,1)')
trace6 = go.Scatter(x=[1, 2], y=[1, 2], name='(5,2)')

fig = tools.make_subplots(rows=5, cols=2,
                          specs=[[{}, {'rowspan': 2}],
                                 [{}, None],
                                 [{'rowspan': 2, 'colspan': 2}, None],
                                 [None, None],
                                 [{}, {}]],
                          print_grid=True)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 2, 1)
fig.append_trace(trace4, 3, 1)
fig.append_trace(trace5, 5, 1)
fig.append_trace(trace6, 5, 2)

fig['layout'].update(height=600, width=600, title='specs examples')
#plot_url = py.plot(fig, filename='Specs-examples-test')
py.iplot(fig, filename='Specs-examples-test')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]         |
# [ (3,1) x4,y4           -      ]
#        |                |
# [ (5,1) x5,y5 ]  [ (5,2) x6,y6 ]
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bbardak37/194.embed" height="600px" width="600px"></iframe>

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
